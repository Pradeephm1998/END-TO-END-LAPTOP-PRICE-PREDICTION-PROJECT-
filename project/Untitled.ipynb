# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.flipkart.com/hp-15s-intel-core-i3-11th-gen-8-gb-512-gb-ssd-windows-11-home-15s-fr2511tu-thin-light-laptop/p/itm89ae6cdc52fdc?pid=COMGG3S9ZPRYMXS5&lid=LSTCOMGG3S9ZPRYMXS5I5YSF2&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=organic&iid=en_mtqMYW66WslyyOQusP1Yb25iiqF%2Bia7Rg61uVgbyiShDx%2Bu3I4yx9xk9L1NGcUAQ95D%2Brnt8xXtRrhdE9ibcGw%3D%3D&ppt=hp&ppn=homepage&ssid=15vdqo3dkw0000001677532153070&qH=312f91285e048e09',headers=headers).text

# %%
webpage
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.a47a6a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57"
# ...

# %%
soup=BeautifulSoup(webpage,'html.parser')

# %%
# Out:
# <!DOCTYPE html>
# ...

# %%
Specifications=soup.find_all('tr',class_="_1s_Smc row")

# %%
pradeep =[]
hi = []
for ultag in soup.find_all('tr', {'class': '_1s_Smc row'}):
        for litag in ultag.find_all('td',class_="_1hKmbr col col-3-12"):
            if litag.text == 'Sales Package':
                for t in ultag.find('li',class_="_21lJbe"):
                    pradeep.append(t.text)

# %%
pradeep
# Out:
# ['Laptop, Power Adapter, User Guide, Warranty Documents']

# %%
hi
# Out:
# []

# %%
Specifications
# Out:
# [<tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Sales Package</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Laptop, Power Adapter, User Guide, Warranty Documents</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">15s-fr2511TU</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Part Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">6N049PA#ACJ</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">15s-fr2511TU</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Series</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">15s Intel</li></ul></td></tr>,
# ...

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.flipkart.com/hp-15s-intel-core-i3-11th-gen-8-gb-512-gb-ssd-windows-11-home-15s-fr2511tu-thin-light-laptop/p/itm89ae6cdc52fdc?pid=COMGG3S9ZPRYMXS5&lid=LSTCOMGG3S9ZPRYMXS5I5YSF2&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=organic&iid=en_mtqMYW66WslyyOQusP1Yb25iiqF%2Bia7Rg61uVgbyiShDx%2Bu3I4yx9xk9L1NGcUAQ95D%2Brnt8xXtRrhdE9ibcGw%3D%3D&ppt=hp&ppn=homepage&ssid=15vdqo3dkw0000001677532153070&qH=312f91285e048e09',headers=headers).text

# %%
urls =["https://www.flipkart.com/redmibook-pro-core-i5-11th-gen-8-gb-512-gb-ssd-windows-11-home-thin-light-laptop/p/itm436427e982703?pid=COMG4Z359A4Z3MFG&lid=LSTCOMG4Z359A4Z3MFGOJQLGB&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=organic&iid=en_tmbmmdZ7v1R9pjBAl0%2BDRXvPzOdlx%2BwQ8iYmaMRuEB3V4cwVps0nm0M%2F%2FvIC4%2BOGTj1Hc3YfkkZizBLEZSepeg%3D%3D&ppt=hp&ppn=homepage&ssid=ukglajs9000000001677588134837&qH=312f91285e048e09",'https://www.flipkart.com/lenovo-ideapad-core-i5-11th-gen-16-gb-512-gb-ssd-windows-11-home-5-15itl05-thin-light-laptop/p/itm8ac843a4857ec?pid=COMGAM8DB9BESKN2&lid=LSTCOMGAM8DB9BESKN2BEXRO0&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=organic&iid=en_tmbmmdZ7v1R9pjBAl0%2BDRXvPzOdlx%2BwQ8iYmaMRuEB1lQCDf3oVSuN3Ih5KetvRQlerN0YtJOH1P3FuVOqOVKA%3D%3D&ppt=hp&ppn=homepage&ssid=ukglajs9000000001677588134837&qH=312f91285e048e09','https://www.flipkart.com/asus-tuf-gaming-f15-core-i5-10th-gen-8-gb-512-gb-ssd-windows-11-home-4-graphics-nvidia-geforce-gtx-1650-144-hz-fx506lhb-hn358w-laptop/p/itm4d930ab779cbd?pid=COMGF9Z7JYCFBKAP&lid=LSTCOMGF9Z7JYCFBKAPXYET0O&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&spotlightTagId=BestsellerId_6bo%2Fb5g&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=search-autosuggest&iid=a6765329-abf8-4bf5-974c-49deb183f170.COMGF9Z7JYCFBKAP.SEARCH&ppt=sp&ppn=sp&qH=312f91285e048e09']

# %%
urls[2]
# Out:
# 'https://www.flipkart.com/asus-tuf-gaming-f15-core-i5-10th-gen-8-gb-512-gb-ssd-windows-11-home-4-graphics-nvidia-geforce-gtx-1650-144-hz-fx506lhb-hn358w-laptop/p/itm4d930ab779cbd?pid=COMGF9Z7JYCFBKAP&lid=LSTCOMGF9Z7JYCFBKAPXYET0O&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&spotlightTagId=BestsellerId_6bo%2Fb5g&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=search-autosuggest&iid=a6765329-abf8-4bf5-974c-49deb183f170.COMGF9Z7JYCFBKAP.SEARCH&ppt=sp&ppn=sp&qH=312f91285e048e09'

# %%
prices = []
titles = []
allSpecifications =[]
for i in urls:
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage=requests.get(i,headers=headers).text
    soup=BeautifulSoup(webpage,'html.parser')
    Specifications=soup.find_all('tr',class_="_1s_Smc row")
    title=soup.find_all('h1',class_="yhB1nd")
    price=soup.find_all('div',class_="_30jeq3 _16Jk6d")
    allSpecifications.append(Specifications)
    titles.append(title)
    prices.append(price)

# %%
len(allSpecifications[2])_30jeq3 _16Jk6d
# Out:
# 58

# %%
prices
# Out:
# [[<div class="_30jeq3 _16Jk6d">₹39,990</div>],
#  [<div class="_30jeq3 _16Jk6d">₹67,999</div>],
#  [<div class="_30jeq3 _16Jk6d">₹49,990</div>]]

# %%
price = []
for  i in prices:
    for  j in  i :
        price.append(j.text)

# %%
price
# Out:
# ['₹39,990', '₹67,999', '₹49,990']

# %%
titles
# Out:
# [[<h1 class="yhB1nd"><span class="B_NuCI">RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop<!-- -->  (15.6 inch, Charcoal Gray, 1.8 kg, With MS Office)</span></h1>],
#  [<h1 class="yhB1nd"><span class="B_NuCI">Lenovo IdeaPad Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) IdeaPad 5 15ITL05 Thin and Light Laptop<!-- -->  (15.6 Inch, Graphite Grey, 1.66 Kg, With MS Office)</span></h1>],
#  [<h1 class="yhB1nd"><span class="B_NuCI">ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 1650/144 Hz) FX506LHB-HN358W Gaming Laptop<!-- -->  (15.6 inch, Black Plastic, 2.30 kg kg)</span></h1>]]

# %%
header = []
for  i in titles:
    for  j in  i :
        header.append(j.text)

# %%
header
# Out:
# ['RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop\xa0\xa0(15.6 inch, Charcoal Gray, 1.8 kg, With MS Office)',
#  'Lenovo IdeaPad Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) IdeaPad 5 15ITL05 Thin and Light Laptop\xa0\xa0(15.6 Inch, Graphite Grey, 1.66 Kg, With MS Office)',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 1650/144 Hz) FX506LHB-HN358W Gaming Laptop\xa0\xa0(15.6 inch, Black Plastic, 2.30 kg kg)']

# %%
allSpecifications
# Out:
# [[<tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Sales Package</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Laptop, 1 Power Adaptor, 1 Power cord, User Manual</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">JYU4431IN/JYU4446IN</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Part Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">JYU4446IN</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">RedmiBook 15 Pro</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Series</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">15 Pro</li></ul></td></tr>,
# ...

# %%
hi =[]
for  i in  allSpecifications:
    pradeep =[]
    for j in i:
        for litag in j.find('td',class_="_1hKmbr col col-3-12"):
            if litag.text == 'Battery Backup':
                for t in j.find('li',class_="_21lJbe"):
                    pradeep.append(t.text)
                
    hi.append(pradeep)

# %%
hi
# Out:
# [['Up to 10 hours'], ['Upto 11 hours'], []]

# %%
def is_empty(list_item):
    if list_item == []:
        return True
    else:
        return False

# %%
result = []
for i in hi:
    if is_empty(i):
        result.append('nan')
    else:
         result.append(i)
# Out:
# [['Up to 10 hours'], ['Upto 11 hours'], 'nan']

# %%
result
# Out:
# [['Up to 10 hours'], ['Upto 11 hours'], 'nan']

# %%
hi =[]
for  i in  allSpecifications:
    hi.append(i)

# %%
hi
# Out:
# [[<tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Sales Package</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Laptop, 1 Power Adaptor, 1 Power cord, User Manual</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">JYU4431IN/JYU4446IN</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Part Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">JYU4446IN</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">RedmiBook 15 Pro</li></ul></td></tr>,
#   <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Series</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">15 Pro</li></ul></td></tr>,
# ...

# %%
hi =[]
for  i in  allSpecifications:
    pradeep =[]
    for j in i:
        for litag in j.find('td',class_="_1hKmbr col col-3-12"):
            if litag.text == 'Processor Name':
                for t in j.find('li',class_="_21lJbe"):
                    pradeep.append(t.text)
                
    hi.append(pradeep)

# %%
hi
# Out:
# [['Core i5'], ['Core i5'], ['Core i5']]

# %%
def is_empty(list_item):
    if list_item == []:
        return True
    else:
        return False

# %%
result = []
for i in Battery_Backup:
    if is_empty(i):
        result.append([np.nan])
    else:
         result.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9388\646272323.py in <module>
#       1 result = []
# ----> 2 for i in Battery_Backup:
#       3     if is_empty(i):
#       4         result.append([np.nan])
#       5     else:
#
# NameError: name 'Battery_Backup' is not defined

# %%
result
# Out:
# []

# %%
result = [element for innerList in result for element in innerList]

# %%
df['FullName'] = df[['First_Name', 'Last_Name']].apply(lambda x: '_'.join(x), axis=1)
df
